# %%
import revisitpy_server as rs
process = rs.serve()
# Out:
# Server is running in the background at http://localhost:8080

# %%
rs.serve().terminate()
# Out:
# Server is running in the background at http://localhost:8080
